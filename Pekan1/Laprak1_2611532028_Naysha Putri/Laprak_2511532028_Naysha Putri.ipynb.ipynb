# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **STRUKTUR DATA**
#
# **“JUDUL MODUL PRAKTIKUM”**
#
# **Disusun Oleh :**
#
# **Naysha Putri**
#
# **2611532028**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Rifkiy Yuliandra**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum "Pengenalan bahasa Python, GitHub, dan VS Code" yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Algoritma Pemrograman. Praktikum ini berfokus pada pembahasan mengenai pengenalan Pyton, pembuatan akun dan pengelolaan GitHub, dan VS Code.
#
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep sebuah sistem yang menggunakan bahasa pemrograman python pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# <Div align=right>
# Padang, 3 September 2026
#
#
#
#
# Naysha Putri

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam Jurusan Informatika, penting bagi mahasiswa untuk mempelajari bahasa pemrograman karena pemrograman merupakan dasar dalam pengembangan teknologi dan perangkat lunak. Salah satu bahasa yang mudah dipelajari adalah Python karena memiliki sintaks yang sederhana dan dapat digunakan dalam berbagai bidang.
#
# Selain mempelajari Python, mahasiswa juga perlu mengenal tools yang mendukung proses pemrograman, seperti Visual Studio Code (VS Code) untuk menulis dan menjalankan kode serta GitHub untuk menyimpan dan mengelola proyek secara daring. Dengan mempelajari ketiganya, mahasiswa dapat meningkatkan keterampilan dasar pemrograman dan mempersiapkan diri untuk mempelajari teknologi yang lebih lanjut.
#
# ## 1.2 Tujuan
# 1. Mengetahui cara menggunakan fitur dasar VS Code untuk menulis, mengedit, dan menjalankan kode program.
# 2. Mempelajari cara menggunakan GitHub untuk menyimpan, membagikan, dan mengelola perubahan pada suatu proyek.
# 3. Memahami konse dasar bahasa pemrograman Python.
# 4. Mampu membuat program sederhana menggunakan bahasa pemrograman Python.
#
# ## 1.3 Manfaat
# 1. Meningkatkan kemampuan dalam menulis dan mengembangkan kode program menggunakan VS Code.
# 2. Mempermudah proses penyimpanan dan pengelolaan proyek melalui GitHub.
# 3. Memahami konsep dasar pengelolaan versi atau perubahan kode dalam suatu proyek.
# 4. Menjadi dasar untuk mempelajari bidang pemrograman yang lebih lanjut, seperti pengembangan aplikasi, pengelolaan data, dan kecerdasan buatan.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Python adalah bahasa pemrograman yang banyak digunakan dalam aplikasi web, pengembangan perangkat lunak, ilmu data, dan machine learning (ML). Banyak developer menggunakan Python karena efisien dan mudah dipelajari serta dapat dijalankan di berbagai platform. Python ini dikembangkan oleh Guido Van Rossum pada tahun 1990 di CWI, Amsterdam.
# Bahasa Python memiliki beberapa kasus penggunaan dalam pengembangan aplikasi, seperti:
#
# 1. Pengembangan web sisi server.
# 2. Otomasi dengan skrip Python.
# 3. Ilmu data dan machine learning.
# 4. Pengembangan perangkat lunak.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "B_2611532028"
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello World")
print()
print("program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a\n" 
+ "Naysha dan 2611532028.")

# %% [markdown]
# **Penjelasan :**
# 1. Bagian pertama menggunakan tanda # dimana komentar tidak akan dijalankan oleh Python dan biasanya digunakan untuk memberikan keterangan atau penjelasan pada kode.
# 2. Bagian kedua sampai bagian kelima menggunakan tanda """ digunakan untuk menulis teks dalam bebrapa baris.
# 3. Bagian keenam berfungsi untuk menampilkan teks "Hello World" ke layar.
# 4. Bagian ketujuh berfungsi untuk membuat satu baris kosong pada output.
# 5. Bagian kedelapan berfungsi untuk menampilkan teks "program ini menghasilkan" ke layar.
# 6. Bagian kesembilan berfungsi untuk menampilkan teks "Empat baris output" ke layar.
# 7. Bagian kesepuluh berfungsi untuk menampilkan "/ \\ // \\\\ /// \\\\\\" ke layar.
# 8. Bagian kesebelas berfungsi untuk menampilkan teks "program ini" + "dibuat oleh a\n" + "Naysha dan 2611532028." ke layar.

# %% [markdown]
# ### 2.2.2 Program Driver "NamaDriver_2611532028"

# %%
# Program pertama
"""
Komentar
dua baris atau lebih
Pertemuan 1 Praktikum alpro
"""
print("Hello World")
print()
print("Program ini menghasilkan")
print("Empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a\n" + "nama dan nim.")

# %% [markdown]
# Pada Pemrograman di atas berisi pemrograman dalam bahasa Python tentang bagaimana kita menulis sebuah teks dan hasilnya dapat ditampilkan ke layar dengan kode print.
#
# Dan dari pemrograman di atas menghasilkan output:
#
# <div align="center">
# <img src="images/output1.png" width="400"><br>
# <em>Gambar 2.1 : Output Program</em>
# </div>

# %% [markdown]
# ---
# ## Tugas Praktikum
#
# **Soal :**
#
# <div align="center">
# <img src="images/tugas1.png" width="500"><br>
# <em>Gambar 2.2 : Soal Tugas Praktikum</em>
# </div>

# %% [markdown]
# **Kode Jawaban :**
#
# a. Kode Program "tugas1_2611532028"

# %%
print("Tugas ini dibuat oleh")
print()
print("Nama: Naysha Putri")
print("NIM: 2611532028")
print("Kelas: Praktikum B")
print()
print("Sekian, terimkasih.")

# %% [markdown]
# **Output :**
#
# <div align="center">
# <img src="images/jawaban.png" width="400"><br>
# <em>Gambar 2.3 : Output Tugas Praktikum</em>
# </div>
#
# **Penjelasan :** Program tugas ini memuat operasi print sehingga mencetak beberapa teks singkat.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python merupakan bahasa pemrograman yang memiliki sintaks sederhana dan sesuai untuk mempelajari dasar pemrograman. Visual Studio Code dapat digunakan untuk menulis, menjalankan, dan mengembangkan program Python dengan berbagai fitur pendukung. Selain itu, GitHub dapat dimanfaatkan untuk menyimpan dan mengelola kode program secara daring melalui repository. Melalui praktikum ini, mahasiswa memperoleh pemahaman dasar mengenai penggunaan Python, VS Code, serta proses menghubungkan dan mengunggah proyek ke GitHub.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] https://repository.umj.ac.id/12892/1/Pemrograman%20Komputer%20FULL.pdf
#
# [2] Penulis, "Judul Buku/Diktat," [Tahun], Hal. ...
